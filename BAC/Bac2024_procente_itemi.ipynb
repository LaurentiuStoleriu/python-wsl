# %% [markdown]
# Prelucrare procente din fisier cu medii pe itemi

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()
# %matplotlib inline
pd.options.display.max_rows = 25

# %%
df = pd.read_csv('/mnt/e/Stoleriu/OneDrive-UAIC/SciComp/Bac2024/tot-itemi.csv', sep = ",")
#print(df)

# %% [markdown]
# ['SIIIR', 'Judet', 'NrCorecturi', 'DiferentaIni', 'I.I', 'I.2', 'I.3', 'I.4', 'I.5', 'I.6', 'I', 'II.1a', 'II.1b', 'II.1c', 'II.2a', 'II.2b', 'II.2c' , 'II', 'III.1a', 'III.1b', 'III.1c', 'III.2a', 'III.2b', 'III.2c', 'III',  'Nota']

# %%
Diferente_column = df[df['DiferentaIni'] > 10.0]
#Diferente_column = Diferente_column['DiferentaIni']

# %%
#Diferente_column.plot.hist(bins=50, alpha=0.5)
#df[['I','II', 'III']].plot(kind='hist', bins=[-2.5,2.5,7.5,12.5,17.5,22.5,27.5,32.5], rwidth=0.9, alpha=0.5)

df[['I']].plot(kind='hist', bins=[-2.5,2.5,7.5,12.5,17.5,22.5,27.5,32.5], rwidth=0.9, alpha=0.5,ylim=(0,45000), color = 'indianred')
df[['II']].plot(kind='hist', bins=[-2.5,2.5,7.5,12.5,17.5,22.5,27.5,32.5], rwidth=0.9, alpha=0.5,ylim=(0,45000), color = 'forestgreen')
df[['III']].plot(kind='hist', bins=[-2.5,2.5,7.5,12.5,17.5,22.5,27.5,32.5], rwidth=0.9, alpha=0.5,ylim=(0,45000), color = 'deepskyblue')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df[['I']].plot(kind='hist', bins=[0, 5, 10, 15, 20, 25, 30], rwidth=0.9, alpha=0.5, color = 'indianred')
df[['II']].plot(kind='hist', bins=[-2.5,2.5,7.5,12.5,17.5,22.5,27.5,32.5], rwidth=0.9, alpha=0.5,ylim=(0,45000), color = 'forestgreen')
df[['III']].plot(kind='hist', bins=[-2.5,2.5,7.5,12.5,17.5,22.5,27.5,32.5], rwidth=0.9, alpha=0.5,ylim=(0,45000), color = 'deepskyblue')
# Out:
# <Axes: ylabel='Frequency'>
